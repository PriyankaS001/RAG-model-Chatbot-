# %%
import ollama

# Load multiple datasets
datasets = []

# Load the first dataset
with open('cn.txt', 'r') as file:
    dataset = file.readlines()
    datasets.append(dataset)
    print(f'Loaded {len(dataset)} entries from cn.txt')

# Load the second dataset
with open('AI.txt', 'r') as file:
    dataset = file.readlines()
    datasets.append(dataset)
    print(f'Loaded {len(dataset)} entries from AI.txt')

# Load the third dataset (if any)
with open('cd.txt', 'r') as file:
    dataset = file.readlines()
    datasets.append(dataset)
    print(f'Loaded {len(dataset)} entries from cd.txt')

# Combine all datasets into one
combined_dataset = [item for sublist in datasets for item in sublist]
print(f'Total entries after combining datasets: {len(combined_dataset)}')

# Implement the retrieval system

EMBEDDING_MODEL = 'hf.co/CompendiumLabs/bge-base-en-v1.5-gguf'
LANGUAGE_MODEL = 'hf.co/bartowski/Llama-3.2-1B-Instruct-GGUF'

# Each element in the VECTOR_DB will be a tuple (chunk, embedding)
# The embedding is a list of floats, for example: [0.1, 0.04, -0.34, 0.21, ...]
VECTOR_DB = []

def add_chunk_to_database(chunk):
    embedding = ollama.embed(model=EMBEDDING_MODEL, input=chunk)['embeddings'][0]
    VECTOR_DB.append((chunk, embedding))

# Add chunks from the combined dataset to the vector database
for i, chunk in enumerate(combined_dataset):
    add_chunk_to_database(chunk)
    print(f'Added chunk {i + 1}/{len(combined_dataset)} to the database')

def cosine_similarity(a, b):
    dot_product = sum([x * y for x, y in zip(a, b)])
    norm_a = sum([x ** 2 for x in a]) ** 0.5
    norm_b = sum([x ** 2 for x in b]) ** 0.5
    return dot_product / (norm_a * norm_b)

def retrieve(query, top_n=3):
    query_embedding = ollama.embed(model=EMBEDDING_MODEL, input=query)['embeddings'][0]
    # Temporary list to store (chunk, similarity) pairs
    similarities = []
    for chunk, embedding in VECTOR_DB:
        similarity = cosine_similarity(query_embedding, embedding)
        similarities.append((chunk, similarity))
    # Sort by similarity in descending order, because higher similarity means more relevant chunks
    similarities.sort(key=lambda x: x[1], reverse=True)
    # Finally, return the top N most relevant chunks
    return similarities[:top_n]

# Chatbot
input_query = input('Ask me a question: ')
retrieved_knowledge = retrieve(input_query)

print('Retrieved knowledge:')
for chunk, similarity in retrieved_knowledge:
    print(f' - (similarity: {similarity:.2f}) {chunk}')

instruction_prompt = f'''You are a helpful chatbot.
Use only the following pieces of context to answer the question. Don't make up any new information:
{'\n'.join([f' - {chunk}' for chunk, similarity in retrieved_knowledge])}
'''

stream = ollama.chat(
    model=LANGUAGE_MODEL,
    messages=[
        {'role': 'system', 'content': instruction_prompt},
        {'role': 'user', 'content': input_query},
    ],
    stream=True,
)

# Print the response from the chatbot in real-time
print('Chatbot response:')
for chunk in stream:
    print(chunk['message']['content'], end='', flush=True)
# Out:
# Loaded 4295 entries from cn.txt
# Loaded 89 entries from AI.txt
# Loaded 4689 entries from cd.txt
# Total entries after combining datasets: 9073
# Added chunk 1/9073 to the database
# Added chunk 2/9073 to the database
# Added chunk 3/9073 to the database
# Added chunk 4/9073 to the database
# Added chunk 5/9073 to the database
# Added chunk 6/9073 to the database
# Added chunk 7/9073 to the database
# Added chunk 8/9073 to the database
# Added chunk 9/9073 to the database
# Added chunk 10/9073 to the database
# Added chunk 11/9073 to the database
# Added chunk 12/9073 to the database
# Added chunk 13/9073 to the database
# Added chunk 14/9073 to the database
# Added chunk 15/9073 to the database
# Added chunk 16/9073 to the database
# Added chunk 17/9073 to the database
# Added chunk 18/9073 to the database
# Added chunk 19/9073 to the database
# Added chunk 20/9073 to the database
# Added chunk 21/9073 to the database
# Added chunk 22/9073 to the database
# Added chunk 23/9073 to the database
# Added chunk 24/9073 to the database
# Added chunk 25/9073 to the database
# Added chunk 26/9073 to the database
# Added chunk 27/9073 to the database
# Added chunk 28/9073 to the database
# Added chunk 29/9073 to the database
# Added chunk 30/9073 to the database
# Added chunk 31/9073 to the database
# Added chunk 32/9073 to the database
# Added chunk 33/9073 to the database
# Added chunk 34/9073 to the database
# Added chunk 35/9073 to the database
# Added chunk 36/9073 to the database
# Added chunk 37/9073 to the database
# Added chunk 38/9073 to the database
# Added chunk 39/9073 to the database
# Added chunk 40/9073 to the database
# Added chunk 41/9073 to the database
# Added chunk 42/9073 to the database
# Added chunk 43/9073 to the database
# Added chunk 44/9073 to the database
# Added chunk 45/9073 to the database
# Added chunk 46/9073 to the database
# Added chunk 47/9073 to the database
# Added chunk 48/9073 to the database
# Added chunk 49/9073 to the database
# Added chunk 50/9073 to the database
# Added chunk 51/9073 to the database
# Added chunk 52/9073 to the database
# Added chunk 53/9073 to the database
# Added chunk 54/9073 to the database
# Added chunk 55/9073 to the database
# Added chunk 56/9073 to the database
# Added chunk 57/9073 to the database
# Added chunk 58/9073 to the database
# Added chunk 59/9073 to the database
# Added chunk 60/9073 to the database
# Added chunk 61/9073 to the database
# Added chunk 62/9073 to the database
# Added chunk 63/9073 to the database
# Added chunk 64/9073 to the database
# Added chunk 65/9073 to the database
# Added chunk 66/9073 to the database
# Added chunk 67/9073 to the database
# Added chunk 68/9073 to the database
# Added chunk 69/9073 to the database
# Added chunk 70/9073 to the database
# Added chunk 71/9073 to the database
# Added chunk 72/9073 to the database
# Added chunk 73/9073 to the database
# Added chunk 74/9073 to the database
# Added chunk 75/9073 to the database
# Added chunk 76/9073 to the database
# Added chunk 77/9073 to the database
# Added chunk 78/9073 to the database
# Added chunk 79/9073 to the database
# Added chunk 80/9073 to the database
# Added chunk 81/9073 to the database
# Added chunk 82/9073 to the database
# Added chunk 83/9073 to the database
# Added chunk 84/9073 to the database
# Added chunk 85/9073 to the database
# Added chunk 86/9073 to the database
# Added chunk 87/9073 to the database
# Added chunk 88/9073 to the database
# Added chunk 89/9073 to the database
# Added chunk 90/9073 to the database
# Added chunk 91/9073 to the database
# Added chunk 92/9073 to the database
# Added chunk 93/9073 to the database
# Added chunk 94/9073 to the database
# Added chunk 95/9073 to the database
# Added chunk 96/9073 to the database
# Added chunk 97/9073 to the database
# Added chunk 98/9073 to the database
# Added chunk 99/9073 to the database
# Added chunk 100/9073 to the database
# Added chunk 101/9073 to the database
# Added chunk 102/9073 to the database
# Added chunk 103/9073 to the database
# Added chunk 104/9073 to the database
# Added chunk 105/9073 to the database
# Added chunk 106/9073 to the database
# Added chunk 107/9073 to the database
# Added chunk 108/9073 to the database
# Added chunk 109/9073 to the database
# Added chunk 110/9073 to the database
# Added chunk 111/9073 to the database
# Added chunk 112/9073 to the database
# Added chunk 113/9073 to the database
# Added chunk 114/9073 to the database
# Added chunk 115/9073 to the database
# Added chunk 116/9073 to the database
# Added chunk 117/9073 to the database
# Added chunk 118/9073 to the database
# Added chunk 119/9073 to the database
# Added chunk 120/9073 to the database
# Added chunk 121/9073 to the database
# Added chunk 122/9073 to the database
# Added chunk 123/9073 to the database
# Added chunk 124/9073 to the database
# Added chunk 125/9073 to the database
# Added chunk 126/9073 to the database
# Added chunk 127/9073 to the database
# Added chunk 128/9073 to the database
# Added chunk 129/9073 to the database
# Added chunk 130/9073 to the database
# Added chunk 131/9073 to the database
# Added chunk 132/9073 to the database
# Added chunk 133/9073 to the database
# Added chunk 134/9073 to the database
# Added chunk 135/9073 to the database
# Added chunk 136/9073 to the database
# Added chunk 137/9073 to the database
# Added chunk 138/9073 to the database
# Added chunk 139/9073 to the database
# Added chunk 140/9073 to the database
# Added chunk 141/9073 to the database
# Added chunk 142/9073 to the database
# Added chunk 143/9073 to the database
# Added chunk 144/9073 to the database
# Added chunk 145/9073 to the database
# Added chunk 146/9073 to the database
# Added chunk 147/9073 to the database
# Added chunk 148/9073 to the database
# Added chunk 149/9073 to the database
# Added chunk 150/9073 to the database
# Added chunk 151/9073 to the database
# Added chunk 152/9073 to the database
# Added chunk 153/9073 to the database
# Added chunk 154/9073 to the database
# Added chunk 155/9073 to the database
# Added chunk 156/9073 to the database
# Added chunk 157/9073 to the database
# Added chunk 158/9073 to the database
# Added chunk 159/9073 to the database
# Added chunk 160/9073 to the database
# Added chunk 161/9073 to the database
# Added chunk 162/9073 to the database
# Added chunk 163/9073 to the database
# Added chunk 164/9073 to the database
# Added chunk 165/9073 to the database
# Added chunk 166/9073 to the database
# Added chunk 167/9073 to the database
# Added chunk 168/9073 to the database
# Added chunk 169/9073 to the database
# Added chunk 170/9073 to the database
# Added chunk 171/9073 to the database
# Added chunk 172/9073 to the database
# Added chunk 173/9073 to the database
# Added chunk 174/9073 to the database
# Added chunk 175/9073 to the database
# Added chunk 176/9073 to the database
# Added chunk 177/9073 to the database
# Added chunk 178/9073 to the database
# Added chunk 179/9073 to the database
# Added chunk 180/9073 to the database
# Added chunk 181/9073 to the database
# Added chunk 182/9073 to the database
# Added chunk 183/9073 to the database
# Added chunk 184/9073 to the database
# Added chunk 185/9073 to the database
# Added chunk 186/9073 to the database
# Added chunk 187/9073 to the database
# Added chunk 188/9073 to the database
# Added chunk 189/9073 to the database
# Added chunk 190/9073 to the database
# Added chunk 191/9073 to the database
# Added chunk 192/9073 to the database
# Added chunk 193/9073 to the database
# Added chunk 194/9073 to the database
# Added chunk 195/9073 to the database
# Added chunk 196/9073 to the database
# Added chunk 197/9073 to the database
# Added chunk 198/9073 to the database
# Added chunk 199/9073 to the database
# Added chunk 200/9073 to the database
# Added chunk 201/9073 to the database
# Added chunk 202/9073 to the database
# Added chunk 203/9073 to the database
# Added chunk 204/9073 to the database
# Added chunk 205/9073 to the database
# Added chunk 206/9073 to the database
# Added chunk 207/9073 to the database
# Added chunk 208/9073 to the database
# Added chunk 209/9073 to the database
# Added chunk 210/9073 to the database
# Added chunk 211/9073 to the database
# Added chunk 212/9073 to the database
# Added chunk 213/9073 to the database
# Added chunk 214/9073 to the database
# Added chunk 215/9073 to the database
# Added chunk 216/9073 to the database
# Added chunk 217/9073 to the database
# Added chunk 218/9073 to the database
# Added chunk 219/9073 to the database
# Added chunk 220/9073 to the database
# Added chunk 221/9073 to the database
# Added chunk 222/9073 to the database
# Added chunk 223/9073 to the database
# Added chunk 224/9073 to the database
# Added chunk 225/9073 to the database
# Added chunk 226/9073 to the database
# Added chunk 227/9073 to the database
# Added chunk 228/9073 to the database
# Added chunk 229/9073 to the database
# Added chunk 230/9073 to the database
# Added chunk 231/9073 to the database
# Added chunk 232/9073 to the database
# Added chunk 233/9073 to the database
# Added chunk 234/9073 to the database
# Added chunk 235/9073 to the database
# Added chunk 236/9073 to the database
# Added chunk 237/9073 to the database
# Added chunk 238/9073 to the database
# Added chunk 239/9073 to the database
# Added chunk 240/9073 to the database
# Added chunk 241/9073 to the database
# Added chunk 242/9073 to the database
# Added chunk 243/9073 to the database
# Added chunk 244/9073 to the database
# Added chunk 245/9073 to the database
# Added chunk 246/9073 to the database
# Added chunk 247/9073 to the database
# Added chunk 248/9073 to the database
# Added chunk 249/9073 to the database
# Added chunk 250/9073 to the database
# Added chunk 251/9073 to the database
# Added chunk 252/9073 to the database
# Added chunk 253/9073 to the database
# Added chunk 254/9073 to the database
# Added chunk 255/9073 to the database
# Added chunk 256/9073 to the database
# Added chunk 257/9073 to the database
# Added chunk 258/9073 to the database
# Added chunk 259/9073 to the database
# Added chunk 260/9073 to the database
# Added chunk 261/9073 to the database
# Added chunk 262/9073 to the database
# Added chunk 263/9073 to the database
# Added chunk 264/9073 to the database
# Added chunk 265/9073 to the database
# Added chunk 266/9073 to the database
# Added chunk 267/9073 to the database
# Added chunk 268/9073 to the database
# Added chunk 269/9073 to the database
# Added chunk 270/9073 to the database
# Added chunk 271/9073 to the database
# Added chunk 272/9073 to the database
# Added chunk 273/9073 to the database
# Added chunk 274/9073 to the database
# Added chunk 275/9073 to the database
# Added chunk 276/9073 to the database
# Added chunk 277/9073 to the database
# Added chunk 278/9073 to the database
# Added chunk 279/9073 to the database
# Added chunk 280/9073 to the database
# Added chunk 281/9073 to the database
# Added chunk 282/9073 to the database
# Added chunk 283/9073 to the database
# Added chunk 284/9073 to the database
# Added chunk 285/9073 to the database
# Added chunk 286/9073 to the database
# Added chunk 287/9073 to the database
# Added chunk 288/9073 to the database
# Added chunk 289/9073 to the database
# Added chunk 290/9073 to the database
# Added chunk 291/9073 to the database
# Added chunk 292/9073 to the database
# Added chunk 293/9073 to the database
# Added chunk 294/9073 to the database
# Added chunk 295/9073 to the database
# Added chunk 296/9073 to the database
# Added chunk 297/9073 to the database
# Added chunk 298/9073 to the database
# Added chunk 299/9073 to the database
# Added chunk 300/9073 to the database
# Added chunk 301/9073 to the database
# Added chunk 302/9073 to the database
# Added chunk 303/9073 to the database
# Added chunk 304/9073 to the database
# Added chunk 305/9073 to the database
# Added chunk 306/9073 to the database
# Added chunk 307/9073 to the database
# Added chunk 308/9073 to the database
# Added chunk 309/9073 to the database
# Added chunk 310/9073 to the database
# Added chunk 311/9073 to the database
# Added chunk 312/9073 to the database
# Added chunk 313/9073 to the database
# Added chunk 314/9073 to the database
# Added chunk 315/9073 to the database
# Added chunk 316/9073 to the database
# Added chunk 317/9073 to the database
# Added chunk 318/9073 to the database
# Added chunk 319/9073 to the database
# Added chunk 320/9073 to the database
# Added chunk 321/9073 to the database
# Added chunk 322/9073 to the database
# Added chunk 323/9073 to the database
# Added chunk 324/9073 to the database
# Added chunk 325/9073 to the database
# Added chunk 326/9073 to the database
# Added chunk 327/9073 to the database
# Added chunk 328/9073 to the database
# Added chunk 329/9073 to the database
# Added chunk 330/9073 to the database
# Added chunk 331/9073 to the database
# Added chunk 332/9073 to the database
# Added chunk 333/9073 to the database
# Added chunk 334/9073 to the database
# Added chunk 335/9073 to the database
# Added chunk 336/9073 to the database
# Added chunk 337/9073 to the database
# Added chunk 338/9073 to the database
# Added chunk 339/9073 to the database
# Added chunk 340/9073 to the database
# Added chunk 341/9073 to the database
# Added chunk 342/9073 to the database
# Added chunk 343/9073 to the database
# Added chunk 344/9073 to the database
# Added chunk 345/9073 to the database
# Added chunk 346/9073 to the database
# Added chunk 347/9073 to the database
# Added chunk 348/9073 to the database
# Added chunk 349/9073 to the database
# Added chunk 350/9073 to the database
# Added chunk 351/9073 to the database
# Added chunk 352/9073 to the database
# Added chunk 353/9073 to the database
# Added chunk 354/9073 to the database
# Added chunk 355/9073 to the database
# Added chunk 356/9073 to the database
# Added chunk 357/9073 to the database
# Added chunk 358/9073 to the database
# Added chunk 359/9073 to the database
# Added chunk 360/9073 to the database
# Added chunk 361/9073 to the database
# Added chunk 362/9073 to the database
# Added chunk 363/9073 to the database
# Added chunk 364/9073 to the database
# Added chunk 365/9073 to the database
# Added chunk 366/9073 to the database
# Added chunk 367/9073 to the database
# Added chunk 368/9073 to the database
# Added chunk 369/9073 to the database
# Added chunk 370/9073 to the database
# Added chunk 371/9073 to the database
# Added chunk 372/9073 to the database
# Added chunk 373/9073 to the database
# Added chunk 374/9073 to the database
# Added chunk 375/9073 to the database
# Added chunk 376/9073 to the database
# Added chunk 377/9073 to the database
# Added chunk 378/9073 to the database
# Added chunk 379/9073 to the database
# Added chunk 380/9073 to the database
# Added chunk 381/9073 to the database
# Added chunk 382/9073 to the database
# Added chunk 383/9073 to the database
# Added chunk 384/9073 to the database
# Added chunk 385/9073 to the database
# Added chunk 386/9073 to the database
# Added chunk 387/9073 to the database
# Added chunk 388/9073 to the database
# Added chunk 389/9073 to the database
# Added chunk 390/9073 to the database
# Added chunk 391/9073 to the database
# Added chunk 392/9073 to the database
# Added chunk 393/9073 to the database
# Added chunk 394/9073 to the database
# Added chunk 395/9073 to the database
# Added chunk 396/9073 to the database
# Added chunk 397/9073 to the database
# Added chunk 398/9073 to the database
# Added chunk 399/9073 to the database
# Added chunk 400/9073 to the database
# Added chunk 401/9073 to the database
# Added chunk 402/9073 to the database
# Added chunk 403/9073 to the database
# Added chunk 404/9073 to the database
# Added chunk 405/9073 to the database
# Added chunk 406/9073 to the database
# Added chunk 407/9073 to the database
# Added chunk 408/9073 to the database
# Added chunk 409/9073 to the database
# Added chunk 410/9073 to the database
# Added chunk 411/9073 to the database
# Added chunk 412/9073 to the database
# Added chunk 413/9073 to the database
# Added chunk 414/9073 to the database
# Added chunk 415/9073 to the database
# Added chunk 416/9073 to the database
# Added chunk 417/9073 to the database
# Added chunk 418/9073 to the database
# Added chunk 419/9073 to the database
# Added chunk 420/9073 to the database
# Added chunk 421/9073 to the database
# Added chunk 422/9073 to the database
# Added chunk 423/9073 to the database
# Added chunk 424/9073 to the database
# Added chunk 425/9073 to the database
# Added chunk 426/9073 to the database
# Added chunk 427/9073 to the database
# Added chunk 428/9073 to the database
# Added chunk 429/9073 to the database
# Added chunk 430/9073 to the database
# Added chunk 431/9073 to the database
# Added chunk 432/9073 to the database
# Added chunk 433/9073 to the database
# Added chunk 434/9073 to the database
# Added chunk 435/9073 to the database
# Added chunk 436/9073 to the database
# Added chunk 437/9073 to the database
# Added chunk 438/9073 to the database
# Added chunk 439/9073 to the database
# Added chunk 440/9073 to the database
# Added chunk 441/9073 to the database
# Added chunk 442/9073 to the database
# Added chunk 443/9073 to the database
# Added chunk 444/9073 to the database
# Added chunk 445/9073 to the database
# Added chunk 446/9073 to the database
# Added chunk 447/9073 to the database
# Added chunk 448/9073 to the database
# Added chunk 449/9073 to the database
# Added chunk 450/9073 to the database
# Added chunk 451/9073 to the database
# Added chunk 452/9073 to the database
# Added chunk 453/9073 to the database
# Added chunk 454/9073 to the database
# Added chunk 455/9073 to the database
# Added chunk 456/9073 to the database
# Added chunk 457/9073 to the database
# Added chunk 458/9073 to the database
# Added chunk 459/9073 to the database
# Added chunk 460/9073 to the database
# Added chunk 461/9073 to the database
# Added chunk 462/9073 to the database
# Added chunk 463/9073 to the database
# Added chunk 464/9073 to the database
# Added chunk 465/9073 to the database
# Added chunk 466/9073 to the database
# Added chunk 467/9073 to the database
# Added chunk 468/9073 to the database
# Added chunk 469/9073 to the database
# Added chunk 470/9073 to the database
# Added chunk 471/9073 to the database
# Added chunk 472/9073 to the database
# Added chunk 473/9073 to the database
# Added chunk 474/9073 to the database
# Added chunk 475/9073 to the database
# Added chunk 476/9073 to the database
# Added chunk 477/9073 to the database
# Added chunk 478/9073 to the database
# Added chunk 479/9073 to the database
# Added chunk 480/9073 to the database
# Added chunk 481/9073 to the database
# Added chunk 482/9073 to the database
# Added chunk 483/9073 to the database
# Added chunk 484/9073 to the database
# Added chunk 485/9073 to the database
# Added chunk 486/9073 to the database
# Added chunk 487/9073 to the database
# Added chunk 488/9073 to the database
# Added chunk 489/9073 to the database
# Added chunk 490/9073 to the database
# Added chunk 491/9073 to the database
# Added chunk 492/9073 to the database
# Added chunk 493/9073 to the database
# Added chunk 494/9073 to the database
# Added chunk 495/9073 to the database
# Added chunk 496/9073 to the database
# Added chunk 497/9073 to the database
# Added chunk 498/9073 to the database
# Added chunk 499/9073 to the database
# Added chunk 500/9073 to the database
# Added chunk 501/9073 to the database
# Added chunk 502/9073 to the database
# Added chunk 503/9073 to the database
# Added chunk 504/9073 to the database
# Added chunk 505/9073 to the database
# Added chunk 506/9073 to the database
# Added chunk 507/9073 to the database
# Added chunk 508/9073 to the database
# Added chunk 509/9073 to the database
# Added chunk 510/9073 to the database
# Added chunk 511/9073 to the database
# Added chunk 512/9073 to the database
# Added chunk 513/9073 to the database
# Added chunk 514/9073 to the database
# Added chunk 515/9073 to the database
# Added chunk 516/9073 to the database
# Added chunk 517/9073 to the database
# Added chunk 518/9073 to the database
# Added chunk 519/9073 to the database
# Added chunk 520/9073 to the database
# Added chunk 521/9073 to the database
# Added chunk 522/9073 to the database
# Added chunk 523/9073 to the database
# Added chunk 524/9073 to the database
# Added chunk 525/9073 to the database
# Added chunk 526/9073 to the database
# Added chunk 527/9073 to the database
# Added chunk 528/9073 to the database
# Added chunk 529/9073 to the database
# Added chunk 530/9073 to the database
# Added chunk 531/9073 to the database
# Added chunk 532/9073 to the database
# Added chunk 533/9073 to the database
# Added chunk 534/9073 to the database
# Added chunk 535/9073 to the database
# Added chunk 536/9073 to the database
# Added chunk 537/9073 to the database
# Added chunk 538/9073 to the database
# Added chunk 539/9073 to the database
# Added chunk 540/9073 to the database
# Added chunk 541/9073 to the database
# Added chunk 542/9073 to the database
# Added chunk 543/9073 to the database
# Added chunk 544/9073 to the database
# Added chunk 545/9073 to the database
# Added chunk 546/9073 to the database
# Added chunk 547/9073 to the database
# Added chunk 548/9073 to the database
# Added chunk 549/9073 to the database
# Added chunk 550/9073 to the database
# Added chunk 551/9073 to the database
# Added chunk 552/9073 to the database
# Added chunk 553/9073 to the database
# Added chunk 554/9073 to the database
# Added chunk 555/9073 to the database
# Added chunk 556/9073 to the database
# Added chunk 557/9073 to the database
# Added chunk 558/9073 to the database
# Added chunk 559/9073 to the database
# Added chunk 560/9073 to the database
# Added chunk 561/9073 to the database
# Added chunk 562/9073 to the database
# Added chunk 563/9073 to the database
# Added chunk 564/9073 to the database
# Added chunk 565/9073 to the database
# Added chunk 566/9073 to the database
# Added chunk 567/9073 to the database
# Added chunk 568/9073 to the database
# Added chunk 569/9073 to the database
# Added chunk 570/9073 to the database
# Added chunk 571/9073 to the database
# Added chunk 572/9073 to the database
# Added chunk 573/9073 to the database
# Added chunk 574/9073 to the database
# Added chunk 575/9073 to the database
# Added chunk 576/9073 to the database
# Added chunk 577/9073 to the database
# Added chunk 578/9073 to the database
# Added chunk 579/9073 to the database
# Added chunk 580/9073 to the database
# Added chunk 581/9073 to the database
# Added chunk 582/9073 to the database
# Added chunk 583/9073 to the database
# Added chunk 584/9073 to the database
# Added chunk 585/9073 to the database
# Added chunk 586/9073 to the database
# Added chunk 587/9073 to the database
# Added chunk 588/9073 to the database
# Added chunk 589/9073 to the database
# Added chunk 590/9073 to the database
# Added chunk 591/9073 to the database
# Added chunk 592/9073 to the database
# Added chunk 593/9073 to the database
# Added chunk 594/9073 to the database
# Added chunk 595/9073 to the database
# Added chunk 596/9073 to the database
# Added chunk 597/9073 to the database
# Added chunk 598/9073 to the database
# Added chunk 599/9073 to the database
# Added chunk 600/9073 to the database
# Added chunk 601/9073 to the database
# Added chunk 602/9073 to the database
# Added chunk 603/9073 to the database
# Added chunk 604/9073 to the database
# Added chunk 605/9073 to the database
# Added chunk 606/9073 to the database
# Added chunk 607/9073 to the database
# Added chunk 608/9073 to the database
# Added chunk 609/9073 to the database
# Added chunk 610/9073 to the database
# Added chunk 611/9073 to the database
# Added chunk 612/9073 to the database
# Added chunk 613/9073 to the database
# Added chunk 614/9073 to the database
# Added chunk 615/9073 to the database
# Added chunk 616/9073 to the database
# Added chunk 617/9073 to the database
# Added chunk 618/9073 to the database
# Added chunk 619/9073 to the database
# Added chunk 620/9073 to the database
# Added chunk 621/9073 to the database
# Added chunk 622/9073 to the database
# Added chunk 623/9073 to the database
# Added chunk 624/9073 to the database
# Added chunk 625/9073 to the database
# Added chunk 626/9073 to the database
# Added chunk 627/9073 to the database
# Added chunk 628/9073 to the database
# Added chunk 629/9073 to the database
# Added chunk 630/9073 to the database
# Added chunk 631/9073 to the database
# Added chunk 632/9073 to the database
# Added chunk 633/9073 to the database
# Added chunk 634/9073 to the database
# Added chunk 635/9073 to the database
# Added chunk 636/9073 to the database
# Added chunk 637/9073 to the database
# Added chunk 638/9073 to the database
# Added chunk 639/9073 to the database
# Added chunk 640/9073 to the database
# Added chunk 641/9073 to the database
# Added chunk 642/9073 to the database
# Added chunk 643/9073 to the database
# Added chunk 644/9073 to the database
# Added chunk 645/9073 to the database
# Added chunk 646/9073 to the database
# Added chunk 647/9073 to the database
# Added chunk 648/9073 to the database
# Added chunk 649/9073 to the database
# Added chunk 650/9073 to the database
# Added chunk 651/9073 to the database
# Added chunk 652/9073 to the database
# Added chunk 653/9073 to the database
# Added chunk 654/9073 to the database
# Added chunk 655/9073 to the database
# Added chunk 656/9073 to the database
# Added chunk 657/9073 to the database
# Added chunk 658/9073 to the database
# Added chunk 659/9073 to the database
# Added chunk 660/9073 to the database
# Added chunk 661/9073 to the database
# Added chunk 662/9073 to the database
# Added chunk 663/9073 to the database
# Added chunk 664/9073 to the database
# Added chunk 665/9073 to the database
# Added chunk 666/9073 to the database
# Added chunk 667/9073 to the database
# Added chunk 668/9073 to the database
# Added chunk 669/9073 to the database
# Added chunk 670/9073 to the database
# Added chunk 671/9073 to the database
# Added chunk 672/9073 to the database
# Added chunk 673/9073 to the database
# Added chunk 674/9073 to the database
# Added chunk 675/9073 to the database
# Added chunk 676/9073 to the database
# Added chunk 677/9073 to the database
# Added chunk 678/9073 to the database
# Added chunk 679/9073 to the database
# Added chunk 680/9073 to the database
# Added chunk 681/9073 to the database
# Added chunk 682/9073 to the database
# Added chunk 683/9073 to the database
# Added chunk 684/9073 to the database
# Added chunk 685/9073 to the database
# Added chunk 686/9073 to the database
# Added chunk 687/9073 to the database
# Added chunk 688/9073 to the database
# Added chunk 689/9073 to the database
# Added chunk 690/9073 to the database
# Added chunk 691/9073 to the database
# Added chunk 692/9073 to the database
# Added chunk 693/9073 to the database
# Added chunk 694/9073 to the database
# Added chunk 695/9073 to the database
# Added chunk 696/9073 to the database
# Added chunk 697/9073 to the database
# Added chunk 698/9073 to the database
# Added chunk 699/9073 to the database
# Added chunk 700/9073 to the database
# Added chunk 701/9073 to the database
# Added chunk 702/9073 to the database
# Added chunk 703/9073 to the database
# Added chunk 704/9073 to the database
# Added chunk 705/9073 to the database
# Added chunk 706/9073 to the database
# Added chunk 707/9073 to the database
# Added chunk 708/9073 to the database
# Added chunk 709/9073 to the database
# Added chunk 710/9073 to the database
# Added chunk 711/9073 to the database
# Added chunk 712/9073 to the database
# Added chunk 713/9073 to the database
# Added chunk 714/9073 to the database
# Added chunk 715/9073 to the database
# Added chunk 716/9073 to the database
# Added chunk 717/9073 to the database
# Added chunk 718/9073 to the database
# Added chunk 719/9073 to the database
# Added chunk 720/9073 to the database
# Added chunk 721/9073 to the database
# Added chunk 722/9073 to the database
# Added chunk 723/9073 to the database
# Added chunk 724/9073 to the database
# Added chunk 725/9073 to the database
# Added chunk 726/9073 to the database
# Added chunk 727/9073 to the database
# Added chunk 728/9073 to the database
# Added chunk 729/9073 to the database
# Added chunk 730/9073 to the database
# Added chunk 731/9073 to the database
# Added chunk 732/9073 to the database
# Added chunk 733/9073 to the database
# Added chunk 734/9073 to the database
# Added chunk 735/9073 to the database
# Added chunk 736/9073 to the database
# Added chunk 737/9073 to the database
# Added chunk 738/9073 to the database
# Added chunk 739/9073 to the database
# Added chunk 740/9073 to the database
# Added chunk 741/9073 to the database
# Added chunk 742/9073 to the database
# Added chunk 743/9073 to the database
# Added chunk 744/9073 to the database
# Added chunk 745/9073 to the database
# Added chunk 746/9073 to the database
# Added chunk 747/9073 to the database
# Added chunk 748/9073 to the database
# Added chunk 749/9073 to the database
# Added chunk 750/9073 to the database
# Added chunk 751/9073 to the database
# Added chunk 752/9073 to the database
# Added chunk 753/9073 to the database
# Added chunk 754/9073 to the database
# Added chunk 755/9073 to the database
# Added chunk 756/9073 to the database
# Added chunk 757/9073 to the database
# Added chunk 758/9073 to the database
# Added chunk 759/9073 to the database
# Added chunk 760/9073 to the database
# Added chunk 761/9073 to the database
# Added chunk 762/9073 to the database
# Added chunk 763/9073 to the database
# Added chunk 764/9073 to the database
# Added chunk 765/9073 to the database
# Added chunk 766/9073 to the database
# Added chunk 767/9073 to the database
# Added chunk 768/9073 to the database
# Added chunk 769/9073 to the database
# Added chunk 770/9073 to the database
# Added chunk 771/9073 to the database
# Added chunk 772/9073 to the database
# Added chunk 773/9073 to the database
# Added chunk 774/9073 to the database
# Added chunk 775/9073 to the database
# Added chunk 776/9073 to the database
# Added chunk 777/9073 to the database
# Added chunk 778/9073 to the database
# Added chunk 779/9073 to the database
# Added chunk 780/9073 to the database
# Added chunk 781/9073 to the database
# Added chunk 782/9073 to the database
# Added chunk 783/9073 to the database
# Added chunk 784/9073 to the database
# Added chunk 785/9073 to the database
# Added chunk 786/9073 to the database
# Added chunk 787/9073 to the database
# Added chunk 788/9073 to the database
# Added chunk 789/9073 to the database
# Added chunk 790/9073 to the database
# Added chunk 791/9073 to the database
# Added chunk 792/9073 to the database
# Added chunk 793/9073 to the database
# Added chunk 794/9073 to the database
# Added chunk 795/9073 to the database
# Added chunk 796/9073 to the database
# Added chunk 797/9073 to the database
# Added chunk 798/9073 to the database
# Added chunk 799/9073 to the database
# Added chunk 800/9073 to the database
# Added chunk 801/9073 to the database
# Added chunk 802/9073 to the database
# Added chunk 803/9073 to the database
# Added chunk 804/9073 to the database
# Added chunk 805/9073 to the database
# Added chunk 806/9073 to the database
# Added chunk 807/9073 to the database
# Added chunk 808/9073 to the database
# Added chunk 809/9073 to the database
# Added chunk 810/9073 to the database
# Added chunk 811/9073 to the database
# Added chunk 812/9073 to the database
# Added chunk 813/9073 to the database
# Added chunk 814/9073 to the database
# Added chunk 815/9073 to the database
# Added chunk 816/9073 to the database
# Added chunk 817/9073 to the database
# Added chunk 818/9073 to the database
# Added chunk 819/9073 to the database
# Added chunk 820/9073 to the database
# Added chunk 821/9073 to the database
# Added chunk 822/9073 to the database
# Added chunk 823/9073 to the database
# Added chunk 824/9073 to the database
# Added chunk 825/9073 to the database
# Added chunk 826/9073 to the database
# Added chunk 827/9073 to the database
# Added chunk 828/9073 to the database
# Added chunk 829/9073 to the database
# Added chunk 830/9073 to the database
# Added chunk 831/9073 to the database
# Added chunk 832/9073 to the database
# Added chunk 833/9073 to the database
# Added chunk 834/9073 to the database
# Added chunk 835/9073 to the database
# Added chunk 836/9073 to the database
# Added chunk 837/9073 to the database
# Added chunk 838/9073 to the database
# Added chunk 839/9073 to the database
# Added chunk 840/9073 to the database
# Added chunk 841/9073 to the database
# Added chunk 842/9073 to the database
# Added chunk 843/9073 to the database
# Added chunk 844/9073 to the database
# Added chunk 845/9073 to the database
# Added chunk 846/9073 to the database
# Added chunk 847/9073 to the database
# Added chunk 848/9073 to the database
# Added chunk 849/9073 to the database
# Added chunk 850/9073 to the database
# Added chunk 851/9073 to the database
# Added chunk 852/9073 to the database
# Added chunk 853/9073 to the database
# Added chunk 854/9073 to the database
# Added chunk 855/9073 to the database
# Added chunk 856/9073 to the database
# Added chunk 857/9073 to the database
# Added chunk 858/9073 to the database
# Added chunk 859/9073 to the database
# Added chunk 860/9073 to the database
# Added chunk 861/9073 to the database
# Added chunk 862/9073 to the database
# Added chunk 863/9073 to the database
# Added chunk 864/9073 to the database
# Added chunk 865/9073 to the database
# Added chunk 866/9073 to the database
# Added chunk 867/9073 to the database
# Added chunk 868/9073 to the database
# Added chunk 869/9073 to the database
# Added chunk 870/9073 to the database
# Added chunk 871/9073 to the database
# Added chunk 872/9073 to the database
# Added chunk 873/9073 to the database
# Added chunk 874/9073 to the database
# Added chunk 875/9073 to the database
# Added chunk 876/9073 to the database
# Added chunk 877/9073 to the database
# Added chunk 878/9073 to the database
# Added chunk 879/9073 to the database
# Added chunk 880/9073 to the database
# Added chunk 881/9073 to the database
# Added chunk 882/9073 to the database
# Added chunk 883/9073 to the database
# Added chunk 884/9073 to the database
# Added chunk 885/9073 to the database
# Added chunk 886/9073 to the database
# Added chunk 887/9073 to the database
# Added chunk 888/9073 to the database
# Added chunk 889/9073 to the database
# Added chunk 890/9073 to the database
# Added chunk 891/9073 to the database
# Added chunk 892/9073 to the database
# Added chunk 893/9073 to the database
# Added chunk 894/9073 to the database
# Added chunk 895/9073 to the database
# Added chunk 896/9073 to the database
# Added chunk 897/9073 to the database
# Added chunk 898/9073 to the database
# Added chunk 899/9073 to the database
# Added chunk 900/9073 to the database
# Added chunk 901/9073 to the database
# Added chunk 902/9073 to the database
# Added chunk 903/9073 to the database
# Added chunk 904/9073 to the database
# Added chunk 905/9073 to the database
# Added chunk 906/9073 to the database
# Added chunk 907/9073 to the database
# Added chunk 908/9073 to the database
# Added chunk 909/9073 to the database
# Added chunk 910/9073 to the database
# Added chunk 911/9073 to the database
# Added chunk 912/9073 to the database
# Added chunk 913/9073 to the database
# Added chunk 914/9073 to the database
# Added chunk 915/9073 to the database
# Added chunk 916/9073 to the database
# Added chunk 917/9073 to the database
# Added chunk 918/9073 to the database
# Added chunk 919/9073 to the database
# Added chunk 920/9073 to the database
# Added chunk 921/9073 to the database
# Added chunk 922/9073 to the database
# Added chunk 923/9073 to the database
# Added chunk 924/9073 to the database
# Added chunk 925/9073 to the database
# Added chunk 926/9073 to the database
# Added chunk 927/9073 to the database
# Added chunk 928/9073 to the database
# Added chunk 929/9073 to the database
# Added chunk 930/9073 to the database
# Added chunk 931/9073 to the database
# Added chunk 932/9073 to the database
# Added chunk 933/9073 to the database
# Added chunk 934/9073 to the database
# Added chunk 935/9073 to the database
# Added chunk 936/9073 to the database
# Added chunk 937/9073 to the database
# Added chunk 938/9073 to the database
# Added chunk 939/9073 to the database
# Added chunk 940/9073 to the database
# Added chunk 941/9073 to the database
# Added chunk 942/9073 to the database
# Added chunk 943/9073 to the database
# Added chunk 944/9073 to the database
# Added chunk 945/9073 to the database
# Added chunk 946/9073 to the database
# Added chunk 947/9073 to the database
# Added chunk 948/9073 to the database
# Added chunk 949/9073 to the database
# Added chunk 950/9073 to the database
# Added chunk 951/9073 to the database
# Added chunk 952/9073 to the database
# Added chunk 953/9073 to the database
# Added chunk 954/9073 to the database
# Added chunk 955/9073 to the database
# Added chunk 956/9073 to the database
# Added chunk 957/9073 to the database
# Added chunk 958/9073 to the database
# Added chunk 959/9073 to the database
# Added chunk 960/9073 to the database
# Added chunk 961/9073 to the database
# Added chunk 962/9073 to the database
# Added chunk 963/9073 to the database
# Added chunk 964/9073 to the database
# Added chunk 965/9073 to the database
# Added chunk 966/9073 to the database
# Added chunk 967/9073 to the database
# Added chunk 968/9073 to the database
# Added chunk 969/9073 to the database
# Added chunk 970/9073 to the database
# Added chunk 971/9073 to the database
# Added chunk 972/9073 to the database
# Added chunk 973/9073 to the database
# Added chunk 974/9073 to the database
# Added chunk 975/9073 to the database
# Added chunk 976/9073 to the database
# Added chunk 977/9073 to the database
# Added chunk 978/9073 to the database
# Added chunk 979/9073 to the database
# Added chunk 980/9073 to the database
# Added chunk 981/9073 to the database
# Added chunk 982/9073 to the database
# Added chunk 983/9073 to the database
# Added chunk 984/9073 to the database
# Added chunk 985/9073 to the database
# Added chunk 986/9073 to the database
# Added chunk 987/9073 to the database
# Added chunk 988/9073 to the database
# Added chunk 989/9073 to the database
# Added chunk 990/9073 to the database
# Added chunk 991/9073 to the database
# Added chunk 992/9073 to the database
# Added chunk 993/9073 to the database
# Added chunk 994/9073 to the database
# Added chunk 995/9073 to the database
# Added chunk 996/9073 to the database
# Added chunk 997/9073 to the database
# Added chunk 998/9073 to the database
# Added chunk 999/9073 to the database
# Added chunk 1000/9073 to the database
# Added chunk 1001/9073 to the database
# Added chunk 1002/9073 to the database
# Added chunk 1003/9073 to the database
# Added chunk 1004/9073 to the database
# Added chunk 1005/9073 to the database
# Added chunk 1006/9073 to the database
# Added chunk 1007/9073 to the database
# Added chunk 1008/9073 to the database
# Added chunk 1009/9073 to the database
# Added chunk 1010/9073 to the database
# Added chunk 1011/9073 to the database
# Added chunk 1012/9073 to the database
# Added chunk 1013/9073 to the database
# Added chunk 1014/9073 to the database
# Added chunk 1015/9073 to the database
# Added chunk 1016/9073 to the database
# Added chunk 1017/9073 to the database
# Added chunk 1018/9073 to the database
# Added chunk 1019/9073 to the database
# Added chunk 1020/9073 to the database
# Added chunk 1021/9073 to the database
# Added chunk 1022/9073 to the database
# Added chunk 1023/9073 to the database
# Added chunk 1024/9073 to the database
# Added chunk 1025/9073 to the database
# Added chunk 1026/9073 to the database
# Added chunk 1027/9073 to the database
# Added chunk 1028/9073 to the database
# Added chunk 1029/9073 to the database
# Added chunk 1030/9073 to the database
# Added chunk 1031/9073 to the database
# Added chunk 1032/9073 to the database
# Added chunk 1033/9073 to the database
# Added chunk 1034/9073 to the database
# Added chunk 1035/9073 to the database
# Added chunk 1036/9073 to the database
# Added chunk 1037/9073 to the database
# Added chunk 1038/9073 to the database
# Added chunk 1039/9073 to the database
# Added chunk 1040/9073 to the database
# Added chunk 1041/9073 to the database
# Added chunk 1042/9073 to the database
# Added chunk 1043/9073 to the database
# Added chunk 1044/9073 to the database
# Added chunk 1045/9073 to the database
# Added chunk 1046/9073 to the database
# Added chunk 1047/9073 to the database
# Added chunk 1048/9073 to the database
# Added chunk 1049/9073 to the database
# Added chunk 1050/9073 to the database
# Added chunk 1051/9073 to the database
# Added chunk 1052/9073 to the database
# Added chunk 1053/9073 to the database
# Added chunk 1054/9073 to the database
# Added chunk 1055/9073 to the database
# Added chunk 1056/9073 to the database
# Added chunk 1057/9073 to the database
# Added chunk 1058/9073 to the database
# Added chunk 1059/9073 to the database
# Added chunk 1060/9073 to the database
# Added chunk 1061/9073 to the database
# Added chunk 1062/9073 to the database
# Added chunk 1063/9073 to the database
# Added chunk 1064/9073 to the database
# Added chunk 1065/9073 to the database
# Added chunk 1066/9073 to the database
# Added chunk 1067/9073 to the database
# Added chunk 1068/9073 to the database
# Added chunk 1069/9073 to the database
# Added chunk 1070/9073 to the database
# Added chunk 1071/9073 to the database
# Added chunk 1072/9073 to the database
# Added chunk 1073/9073 to the database
# Added chunk 1074/9073 to the database
# Added chunk 1075/9073 to the database
# Added chunk 1076/9073 to the database
# Added chunk 1077/9073 to the database
# Added chunk 1078/9073 to the database
# Added chunk 1079/9073 to the database
# Added chunk 1080/9073 to the database
# Added chunk 1081/9073 to the database
# Added chunk 1082/9073 to the database
# Added chunk 1083/9073 to the database
# Added chunk 1084/9073 to the database
# Added chunk 1085/9073 to the database
# Added chunk 1086/9073 to the database
# Added chunk 1087/9073 to the database
# Added chunk 1088/9073 to the database
# Added chunk 1089/9073 to the database
# Added chunk 1090/9073 to the database
# Added chunk 1091/9073 to the database
# Added chunk 1092/9073 to the database
# Added chunk 1093/9073 to the database
# Added chunk 1094/9073 to the database
# Added chunk 1095/9073 to the database
# Added chunk 1096/9073 to the database
# Added chunk 1097/9073 to the database
# Added chunk 1098/9073 to the database
# Added chunk 1099/9073 to the database
# Added chunk 1100/9073 to the database
# Added chunk 1101/9073 to the database
# Added chunk 1102/9073 to the database
# Added chunk 1103/9073 to the database
# Added chunk 1104/9073 to the database
# Added chunk 1105/9073 to the database
# Added chunk 1106/9073 to the database
# Added chunk 1107/9073 to the database
# Added chunk 1108/9073 to the database
# Added chunk 1109/9073 to the database
# Added chunk 1110/9073 to the database
# Added chunk 1111/9073 to the database
# Added chunk 1112/9073 to the database
# Added chunk 1113/9073 to the database
# Added chunk 1114/9073 to the database
# Added chunk 1115/9073 to the database
# Added chunk 1116/9073 to the database
# Added chunk 1117/9073 to the database
# Added chunk 1118/9073 to the database
# Added chunk 1119/9073 to the database
# Added chunk 1120/9073 to the database
# Added chunk 1121/9073 to the database
# Added chunk 1122/9073 to the database
# Added chunk 1123/9073 to the database
# Added chunk 1124/9073 to the database
# Added chunk 1125/9073 to the database
# Added chunk 1126/9073 to the database
# Added chunk 1127/9073 to the database
# Added chunk 1128/9073 to the database
# Added chunk 1129/9073 to the database
# Added chunk 1130/9073 to the database
# Added chunk 1131/9073 to the database
# Added chunk 1132/9073 to the database
# Added chunk 1133/9073 to the database
# Added chunk 1134/9073 to the database
# Added chunk 1135/9073 to the database
# Added chunk 1136/9073 to the database
# Added chunk 1137/9073 to the database
# Added chunk 1138/9073 to the database
# Added chunk 1139/9073 to the database
# Added chunk 1140/9073 to the database
# Added chunk 1141/9073 to the database
# Added chunk 1142/9073 to the database
# Added chunk 1143/9073 to the database
# Added chunk 1144/9073 to the database
# Added chunk 1145/9073 to the database
# Added chunk 1146/9073 to the database
# Added chunk 1147/9073 to the database
# Added chunk 1148/9073 to the database
# Added chunk 1149/9073 to the database
# Added chunk 1150/9073 to the database
# Added chunk 1151/9073 to the database
# Added chunk 1152/9073 to the database
# Added chunk 1153/9073 to the database
# Added chunk 1154/9073 to the database
# Added chunk 1155/9073 to the database
# Added chunk 1156/9073 to the database
# Added chunk 1157/9073 to the database
# Added chunk 1158/9073 to the database
# Added chunk 1159/9073 to the database
# Added chunk 1160/9073 to the database
# Added chunk 1161/9073 to the database
# Added chunk 1162/9073 to the database
# Added chunk 1163/9073 to the database
# Added chunk 1164/9073 to the database
# Added chunk 1165/9073 to the database
# Added chunk 1166/9073 to the database
# Added chunk 1167/9073 to the database
# Added chunk 1168/9073 to the database
# Added chunk 1169/9073 to the database
# Added chunk 1170/9073 to the database
# Added chunk 1171/9073 to the database
# Added chunk 1172/9073 to the database
# Added chunk 1173/9073 to the database
# Added chunk 1174/9073 to the database
# Added chunk 1175/9073 to the database
# Added chunk 1176/9073 to the database
# Added chunk 1177/9073 to the database
# Added chunk 1178/9073 to the database
# Added chunk 1179/9073 to the database
# Added chunk 1180/9073 to the database
# Added chunk 1181/9073 to the database
# Added chunk 1182/9073 to the database
# Added chunk 1183/9073 to the database
# Added chunk 1184/9073 to the database
# Added chunk 1185/9073 to the database
# Added chunk 1186/9073 to the database
# Added chunk 1187/9073 to the database
# Added chunk 1188/9073 to the database
# Added chunk 1189/9073 to the database
# Added chunk 1190/9073 to the database
# Added chunk 1191/9073 to the database
# Added chunk 1192/9073 to the database
# Added chunk 1193/9073 to the database
# Added chunk 1194/9073 to the database
# Added chunk 1195/9073 to the database
# Added chunk 1196/9073 to the database
# Added chunk 1197/9073 to the database
# Added chunk 1198/9073 to the database
# Added chunk 1199/9073 to the database
# Added chunk 1200/9073 to the database
# Added chunk 1201/9073 to the database
# Added chunk 1202/9073 to the database
# Added chunk 1203/9073 to the database
# Added chunk 1204/9073 to the database
# Added chunk 1205/9073 to the database
# Added chunk 1206/9073 to the database
# Added chunk 1207/9073 to the database
# Added chunk 1208/9073 to the database
# Added chunk 1209/9073 to the database
# Added chunk 1210/9073 to the database
# Added chunk 1211/9073 to the database
# Added chunk 1212/9073 to the database
# Added chunk 1213/9073 to the database
# Added chunk 1214/9073 to the database
# Added chunk 1215/9073 to the database
# Added chunk 1216/9073 to the database
# Added chunk 1217/9073 to the database
# Added chunk 1218/9073 to the database
# Added chunk 1219/9073 to the database
# Added chunk 1220/9073 to the database
# Added chunk 1221/9073 to the database
# Added chunk 1222/9073 to the database
# Added chunk 1223/9073 to the database
# Added chunk 1224/9073 to the database
# Added chunk 1225/9073 to the database
# Added chunk 1226/9073 to the database
# Added chunk 1227/9073 to the database
# Added chunk 1228/9073 to the database
# Added chunk 1229/9073 to the database
# Added chunk 1230/9073 to the database
# Added chunk 1231/9073 to the database
# Added chunk 1232/9073 to the database
# Added chunk 1233/9073 to the database
# Added chunk 1234/9073 to the database
# Added chunk 1235/9073 to the database
# Added chunk 1236/9073 to the database
# Added chunk 1237/9073 to the database
# Added chunk 1238/9073 to the database
# Added chunk 1239/9073 to the database
# Added chunk 1240/9073 to the database
# Added chunk 1241/9073 to the database
# Added chunk 1242/9073 to the database
# Added chunk 1243/9073 to the database
# Added chunk 1244/9073 to the database
# Added chunk 1245/9073 to the database
# Added chunk 1246/9073 to the database
# Added chunk 1247/9073 to the database
# Added chunk 1248/9073 to the database
# Added chunk 1249/9073 to the database
# Added chunk 1250/9073 to the database
# Added chunk 1251/9073 to the database
# Added chunk 1252/9073 to the database
# Added chunk 1253/9073 to the database
# Added chunk 1254/9073 to the database
# Added chunk 1255/9073 to the database
# Added chunk 1256/9073 to the database
# Added chunk 1257/9073 to the database
# Added chunk 1258/9073 to the database
# Added chunk 1259/9073 to the database
# Added chunk 1260/9073 to the database
# Added chunk 1261/9073 to the database
# Added chunk 1262/9073 to the database
# Added chunk 1263/9073 to the database
# Added chunk 1264/9073 to the database
# Added chunk 1265/9073 to the database
# Added chunk 1266/9073 to the database
# Added chunk 1267/9073 to the database
# Added chunk 1268/9073 to the database
# Added chunk 1269/9073 to the database
# Added chunk 1270/9073 to the database
# Added chunk 1271/9073 to the database
# Added chunk 1272/9073 to the database
# Added chunk 1273/9073 to the database
# Added chunk 1274/9073 to the database
# Added chunk 1275/9073 to the database
# Added chunk 1276/9073 to the database
# Added chunk 1277/9073 to the database
# Added chunk 1278/9073 to the database
# Added chunk 1279/9073 to the database
# Added chunk 1280/9073 to the database
# Added chunk 1281/9073 to the database
# Added chunk 1282/9073 to the database
# Added chunk 1283/9073 to the database
# Added chunk 1284/9073 to the database
# Added chunk 1285/9073 to the database
# Added chunk 1286/9073 to the database
# Added chunk 1287/9073 to the database
# Added chunk 1288/9073 to the database
# ...
# Added chunk 8672/9073 to the database
# Added chunk 8673/9073 to the database
# Added chunk 8674/9073 to the database
# Added chunk 8675/9073 to the database
# Added chunk 8676/9073 to the database
# Added chunk 8677/9073 to the database
# Added chunk 8678/9073 to the database
# Added chunk 8679/9073 to the database
# Added chunk 8680/9073 to the database
# Added chunk 8681/9073 to the database
# Added chunk 8682/9073 to the database
# Added chunk 8683/9073 to the database
# Added chunk 8684/9073 to the database
# Added chunk 8685/9073 to the database
# Added chunk 8686/9073 to the database
# Added chunk 8687/9073 to the database
# Added chunk 8688/9073 to the database
# Added chunk 8689/9073 to the database
# Added chunk 8690/9073 to the database
# Added chunk 8691/9073 to the database
# Added chunk 8692/9073 to the database
# Added chunk 8693/9073 to the database
# Added chunk 8694/9073 to the database
# Added chunk 8695/9073 to the database
# Added chunk 8696/9073 to the database
# Added chunk 8697/9073 to the database
# Added chunk 8698/9073 to the database
# Added chunk 8699/9073 to the database
# Added chunk 8700/9073 to the database
# Added chunk 8701/9073 to the database
# Added chunk 8702/9073 to the database
# Added chunk 8703/9073 to the database
# Added chunk 8704/9073 to the database
# Added chunk 8705/9073 to the database
# Added chunk 8706/9073 to the database
# Added chunk 8707/9073 to the database
# Added chunk 8708/9073 to the database
# Added chunk 8709/9073 to the database
# Added chunk 8710/9073 to the database
# Added chunk 8711/9073 to the database
# Added chunk 8712/9073 to the database
# Added chunk 8713/9073 to the database
# Added chunk 8714/9073 to the database
# Added chunk 8715/9073 to the database
# Added chunk 8716/9073 to the database
# Added chunk 8717/9073 to the database
# Added chunk 8718/9073 to the database
# Added chunk 8719/9073 to the database
# Added chunk 8720/9073 to the database
# Added chunk 8721/9073 to the database
# Added chunk 8722/9073 to the database
# Added chunk 8723/9073 to the database
# Added chunk 8724/9073 to the database
# Added chunk 8725/9073 to the database
# Added chunk 8726/9073 to the database
# Added chunk 8727/9073 to the database
# Added chunk 8728/9073 to the database
# Added chunk 8729/9073 to the database
# Added chunk 8730/9073 to the database
# Added chunk 8731/9073 to the database
# Added chunk 8732/9073 to the database
# Added chunk 8733/9073 to the database
# Added chunk 8734/9073 to the database
# Added chunk 8735/9073 to the database
# Added chunk 8736/9073 to the database
# Added chunk 8737/9073 to the database
# Added chunk 8738/9073 to the database
# Added chunk 8739/9073 to the database
# Added chunk 8740/9073 to the database
# Added chunk 8741/9073 to the database
# Added chunk 8742/9073 to the database
# Added chunk 8743/9073 to the database
# Added chunk 8744/9073 to the database
# Added chunk 8745/9073 to the database
# Added chunk 8746/9073 to the database
# Added chunk 8747/9073 to the database
# Added chunk 8748/9073 to the database
# Added chunk 8749/9073 to the database
# Added chunk 8750/9073 to the database
# Added chunk 8751/9073 to the database
# Added chunk 8752/9073 to the database
# Added chunk 8753/9073 to the database
# Added chunk 8754/9073 to the database
# Added chunk 8755/9073 to the database
# Added chunk 8756/9073 to the database
# Added chunk 8757/9073 to the database
# Added chunk 8758/9073 to the database
# Added chunk 8759/9073 to the database
# Added chunk 8760/9073 to the database
# Added chunk 8761/9073 to the database
# Added chunk 8762/9073 to the database
# Added chunk 8763/9073 to the database
# Added chunk 8764/9073 to the database
# Added chunk 8765/9073 to the database
# Added chunk 8766/9073 to the database
# Added chunk 8767/9073 to the database
# Added chunk 8768/9073 to the database
# Added chunk 8769/9073 to the database
# Added chunk 8770/9073 to the database
# Added chunk 8771/9073 to the database
# Added chunk 8772/9073 to the database
# Added chunk 8773/9073 to the database
# Added chunk 8774/9073 to the database
# Added chunk 8775/9073 to the database
# Added chunk 8776/9073 to the database
# Added chunk 8777/9073 to the database
# Added chunk 8778/9073 to the database
# Added chunk 8779/9073 to the database
# Added chunk 8780/9073 to the database
# Added chunk 8781/9073 to the database
# Added chunk 8782/9073 to the database
# Added chunk 8783/9073 to the database
# Added chunk 8784/9073 to the database
# Added chunk 8785/9073 to the database
# Added chunk 8786/9073 to the database
# Added chunk 8787/9073 to the database
# Added chunk 8788/9073 to the database
# Added chunk 8789/9073 to the database
# Added chunk 8790/9073 to the database
# Added chunk 8791/9073 to the database
# Added chunk 8792/9073 to the database
# Added chunk 8793/9073 to the database
# Added chunk 8794/9073 to the database
# Added chunk 8795/9073 to the database
# Added chunk 8796/9073 to the database
# Added chunk 8797/9073 to the database
# Added chunk 8798/9073 to the database
# Added chunk 8799/9073 to the database
# Added chunk 8800/9073 to the database
# Added chunk 8801/9073 to the database
# Added chunk 8802/9073 to the database
# Added chunk 8803/9073 to the database
# Added chunk 8804/9073 to the database
# Added chunk 8805/9073 to the database
# Added chunk 8806/9073 to the database
# Added chunk 8807/9073 to the database
# Added chunk 8808/9073 to the database
# Added chunk 8809/9073 to the database
# Added chunk 8810/9073 to the database
# Added chunk 8811/9073 to the database
# Added chunk 8812/9073 to the database
# Added chunk 8813/9073 to the database
# Added chunk 8814/9073 to the database
# Added chunk 8815/9073 to the database
# Added chunk 8816/9073 to the database
# Added chunk 8817/9073 to the database
# Added chunk 8818/9073 to the database
# Added chunk 8819/9073 to the database
# Added chunk 8820/9073 to the database
# Added chunk 8821/9073 to the database
# Added chunk 8822/9073 to the database
# Added chunk 8823/9073 to the database
# Added chunk 8824/9073 to the database
# Added chunk 8825/9073 to the database
# Added chunk 8826/9073 to the database
# Added chunk 8827/9073 to the database
# Added chunk 8828/9073 to the database
# Added chunk 8829/9073 to the database
# Added chunk 8830/9073 to the database
# Added chunk 8831/9073 to the database
# Added chunk 8832/9073 to the database
# Added chunk 8833/9073 to the database
# Added chunk 8834/9073 to the database
# Added chunk 8835/9073 to the database
# Added chunk 8836/9073 to the database
# Added chunk 8837/9073 to the database
# Added chunk 8838/9073 to the database
# Added chunk 8839/9073 to the database
# Added chunk 8840/9073 to the database
# Added chunk 8841/9073 to the database
# Added chunk 8842/9073 to the database
# Added chunk 8843/9073 to the database
# Added chunk 8844/9073 to the database
# Added chunk 8845/9073 to the database
# Added chunk 8846/9073 to the database
# Added chunk 8847/9073 to the database
# Added chunk 8848/9073 to the database
# Added chunk 8849/9073 to the database
# Added chunk 8850/9073 to the database
# Added chunk 8851/9073 to the database
# Added chunk 8852/9073 to the database
# Added chunk 8853/9073 to the database
# Added chunk 8854/9073 to the database
# Added chunk 8855/9073 to the database
# Added chunk 8856/9073 to the database
# Added chunk 8857/9073 to the database
# Added chunk 8858/9073 to the database
# Added chunk 8859/9073 to the database
# Added chunk 8860/9073 to the database
# Added chunk 8861/9073 to the database
# Added chunk 8862/9073 to the database
# Added chunk 8863/9073 to the database
# Added chunk 8864/9073 to the database
# Added chunk 8865/9073 to the database
# Added chunk 8866/9073 to the database
# Added chunk 8867/9073 to the database
# Added chunk 8868/9073 to the database
# Added chunk 8869/9073 to the database
# Added chunk 8870/9073 to the database
# Added chunk 8871/9073 to the database
# Added chunk 8872/9073 to the database
# Added chunk 8873/9073 to the database
# Added chunk 8874/9073 to the database
# Added chunk 8875/9073 to the database
# Added chunk 8876/9073 to the database
# Added chunk 8877/9073 to the database
# Added chunk 8878/9073 to the database
# Added chunk 8879/9073 to the database
# Added chunk 8880/9073 to the database
# Added chunk 8881/9073 to the database
# Added chunk 8882/9073 to the database
# Added chunk 8883/9073 to the database
# Added chunk 8884/9073 to the database
# Added chunk 8885/9073 to the database
# Added chunk 8886/9073 to the database
# Added chunk 8887/9073 to the database
# Added chunk 8888/9073 to the database
# Added chunk 8889/9073 to the database
# Added chunk 8890/9073 to the database
# Added chunk 8891/9073 to the database
# Added chunk 8892/9073 to the database
# Added chunk 8893/9073 to the database
# Added chunk 8894/9073 to the database
# Added chunk 8895/9073 to the database
# Added chunk 8896/9073 to the database
# Added chunk 8897/9073 to the database
# Added chunk 8898/9073 to the database
# Added chunk 8899/9073 to the database
# Added chunk 8900/9073 to the database
# Added chunk 8901/9073 to the database
# Added chunk 8902/9073 to the database
# Added chunk 8903/9073 to the database
# Added chunk 8904/9073 to the database
# Added chunk 8905/9073 to the database
# Added chunk 8906/9073 to the database
# Added chunk 8907/9073 to the database
# Added chunk 8908/9073 to the database
# Added chunk 8909/9073 to the database
# Added chunk 8910/9073 to the database
# Added chunk 8911/9073 to the database
# Added chunk 8912/9073 to the database
# Added chunk 8913/9073 to the database
# Added chunk 8914/9073 to the database
# Added chunk 8915/9073 to the database
# Added chunk 8916/9073 to the database
# Added chunk 8917/9073 to the database
# Added chunk 8918/9073 to the database
# Added chunk 8919/9073 to the database
# Added chunk 8920/9073 to the database
# Added chunk 8921/9073 to the database
# Added chunk 8922/9073 to the database
# Added chunk 8923/9073 to the database
# Added chunk 8924/9073 to the database
# Added chunk 8925/9073 to the database
# Added chunk 8926/9073 to the database
# Added chunk 8927/9073 to the database
# Added chunk 8928/9073 to the database
# Added chunk 8929/9073 to the database
# Added chunk 8930/9073 to the database
# Added chunk 8931/9073 to the database
# Added chunk 8932/9073 to the database
# Added chunk 8933/9073 to the database
# Added chunk 8934/9073 to the database
# Added chunk 8935/9073 to the database
# Added chunk 8936/9073 to the database
# Added chunk 8937/9073 to the database
# Added chunk 8938/9073 to the database
# Added chunk 8939/9073 to the database
# Added chunk 8940/9073 to the database
# Added chunk 8941/9073 to the database
# Added chunk 8942/9073 to the database
# Added chunk 8943/9073 to the database
# Added chunk 8944/9073 to the database
# Added chunk 8945/9073 to the database
# Added chunk 8946/9073 to the database
# Added chunk 8947/9073 to the database
# Added chunk 8948/9073 to the database
# Added chunk 8949/9073 to the database
# Added chunk 8950/9073 to the database
# Added chunk 8951/9073 to the database
# Added chunk 8952/9073 to the database
# Added chunk 8953/9073 to the database
# Added chunk 8954/9073 to the database
# Added chunk 8955/9073 to the database
# Added chunk 8956/9073 to the database
# Added chunk 8957/9073 to the database
# Added chunk 8958/9073 to the database
# Added chunk 8959/9073 to the database
# Added chunk 8960/9073 to the database
# Added chunk 8961/9073 to the database
# Added chunk 8962/9073 to the database
# Added chunk 8963/9073 to the database
# Added chunk 8964/9073 to the database
# Added chunk 8965/9073 to the database
# Added chunk 8966/9073 to the database
# Added chunk 8967/9073 to the database
# Added chunk 8968/9073 to the database
# Added chunk 8969/9073 to the database
# Added chunk 8970/9073 to the database
# Added chunk 8971/9073 to the database
# Added chunk 8972/9073 to the database
# Added chunk 8973/9073 to the database
# Added chunk 8974/9073 to the database
# Added chunk 8975/9073 to the database
# Added chunk 8976/9073 to the database
# Added chunk 8977/9073 to the database
# Added chunk 8978/9073 to the database
# Added chunk 8979/9073 to the database
# Added chunk 8980/9073 to the database
# Added chunk 8981/9073 to the database
# Added chunk 8982/9073 to the database
# Added chunk 8983/9073 to the database
# Added chunk 8984/9073 to the database
# Added chunk 8985/9073 to the database
# Added chunk 8986/9073 to the database
# Added chunk 8987/9073 to the database
# Added chunk 8988/9073 to the database
# Added chunk 8989/9073 to the database
# Added chunk 8990/9073 to the database
# Added chunk 8991/9073 to the database
# Added chunk 8992/9073 to the database
# Added chunk 8993/9073 to the database
# Added chunk 8994/9073 to the database
# Added chunk 8995/9073 to the database
# Added chunk 8996/9073 to the database
# Added chunk 8997/9073 to the database
# Added chunk 8998/9073 to the database
# Added chunk 8999/9073 to the database
# Added chunk 9000/9073 to the database
# Added chunk 9001/9073 to the database
# Added chunk 9002/9073 to the database
# Added chunk 9003/9073 to the database
# Added chunk 9004/9073 to the database
# Added chunk 9005/9073 to the database
# Added chunk 9006/9073 to the database
# Added chunk 9007/9073 to the database
# Added chunk 9008/9073 to the database
# Added chunk 9009/9073 to the database
# Added chunk 9010/9073 to the database
# Added chunk 9011/9073 to the database
# Added chunk 9012/9073 to the database
# Added chunk 9013/9073 to the database
# Added chunk 9014/9073 to the database
# Added chunk 9015/9073 to the database
# Added chunk 9016/9073 to the database
# Added chunk 9017/9073 to the database
# Added chunk 9018/9073 to the database
# Added chunk 9019/9073 to the database
# Added chunk 9020/9073 to the database
# Added chunk 9021/9073 to the database
# Added chunk 9022/9073 to the database
# Added chunk 9023/9073 to the database
# Added chunk 9024/9073 to the database
# Added chunk 9025/9073 to the database
# Added chunk 9026/9073 to the database
# Added chunk 9027/9073 to the database
# Added chunk 9028/9073 to the database
# Added chunk 9029/9073 to the database
# Added chunk 9030/9073 to the database
# Added chunk 9031/9073 to the database
# Added chunk 9032/9073 to the database
# Added chunk 9033/9073 to the database
# Added chunk 9034/9073 to the database
# Added chunk 9035/9073 to the database
# Added chunk 9036/9073 to the database
# Added chunk 9037/9073 to the database
# Added chunk 9038/9073 to the database
# Added chunk 9039/9073 to the database
# Added chunk 9040/9073 to the database
# Added chunk 9041/9073 to the database
# Added chunk 9042/9073 to the database
# Added chunk 9043/9073 to the database
# Added chunk 9044/9073 to the database
# Added chunk 9045/9073 to the database
# Added chunk 9046/9073 to the database
# Added chunk 9047/9073 to the database
# Added chunk 9048/9073 to the database
# Added chunk 9049/9073 to the database
# Added chunk 9050/9073 to the database
# Added chunk 9051/9073 to the database
# Added chunk 9052/9073 to the database
# Added chunk 9053/9073 to the database
# Added chunk 9054/9073 to the database
# Added chunk 9055/9073 to the database
# Added chunk 9056/9073 to the database
# Added chunk 9057/9073 to the database
# Added chunk 9058/9073 to the database
# Added chunk 9059/9073 to the database
# Added chunk 9060/9073 to the database
# Added chunk 9061/9073 to the database
# Added chunk 9062/9073 to the database
# Added chunk 9063/9073 to the database
# Added chunk 9064/9073 to the database
# Added chunk 9065/9073 to the database
# Added chunk 9066/9073 to the database
# Added chunk 9067/9073 to the database
# Added chunk 9068/9073 to the database
# Added chunk 9069/9073 to the database
# Added chunk 9070/9073 to the database
# Added chunk 9071/9073 to the database
# Added chunk 9072/9073 to the database
# Added chunk 9073/9073 to the database
# Ask me a question:  what is computer network
# Retrieved knowledge:
#  - (similarity: 0.83) COMPUTER NETWORKS
#
#  - (similarity: 0.77) USES OF COMPUTER NETWORKS
#
#  - (similarity: 0.75) network have connections to multiple other computers in that network. It is an
#
# Chatbot response:
# A computer network is a system of interconnected computers, devices, and other electronic devices that communicate with each other and share resources. This can include hardware such as routers, switches, and servers, and software applications like operating systems and network protocols.
#
# In simple terms, a computer network is a collection of devices connected together to enable communication, sharing, and collaboration between them.
